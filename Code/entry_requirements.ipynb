# %% [markdown]
# <a href="https://colab.research.google.com/github/ttevhide/Women_In_Tech/blob/main/entry_requirements.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import re
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

# %matplotlib inline

df = pd.read_excel(r"https://github.com/ttevhide/Women_In_Tech/blob/main/DataSet/computing_entry_requirements_scotland.xlsx?raw=true")
df
# Out:
#                                 HE provider  Computer Related courses  \
# 0                   University of Edinburgh                        13
# 1                     University of Glasgow                        34
# 2                    University of Aberdeen                        11
# 3                  University of St Andrews                         8
# 4                      University of Dundee                         1
# 5                 University of Strathclyde                         8
# 6                    Heriot-Watt University                        16
# 7                    University of Stirling                         9
# 8             Glasgow Caledonian University                        13
# 9               Edinburgh Napier University                        14
# 10       University of the West of Scotland                         8
# 11                 Robert Gordon University                         9
# ...
