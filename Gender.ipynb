# %% [markdown]
# <a href="https://colab.research.google.com/github/ttevhide/Women_In_Tech/blob/main/Gender.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import janitor
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go

df = pd.read_csv(r"https://raw.githubusercontent.com/ttevhide/Women_In_Tech/main/DataSet/figure-13.csv?raw=true", header=17)
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32941 entries, 0 to 32940
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   01 Medicine and dentistry  32941 non-null  object
#  1   All                        32941 non-null  object
#  2   All.1                      32941 non-null  object
#  3   All.2                      32941 non-null  object
#  4   All.3                      32941 non-null  object
#  5   Other                      32941 non-null  object
#  6   2019/20                    32941 non-null  object
#  7   150                        32941 non-null  int64
# dtypes: int64(1), object(7)
# memory usage: 2.0+ MB
#        01 Medicine and dentistry          All              All.1      All.2  \
# 0      01 Medicine and dentistry          All                All        All
# 1      01 Medicine and dentistry          All                All  Full-time
# ...

# %%
print(df["subject_area"].unique())
print(df["first_year_marker"].unique())
print(dfn["level_of_study"].unique())
print(df["mode_of_study"].unique())
print(df["country_of_he_provider"].unique())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'subject_area'
#
# The above exception was the direct cause of the following exception:
#
# ...
